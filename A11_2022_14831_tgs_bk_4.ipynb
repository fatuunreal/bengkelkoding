# %% [markdown]
# <a href="https://colab.research.google.com/github/fatuunreal/bengkelkoding/blob/4/A11_2022_14831_tgs_bk_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparing model Decision Tree, Random Forest, KNN, Logistic Regression, SVM pada dataset adult.csv
#
# #By : FATU RAHMAT
# #NIM : A11.2022.14831

# %% [markdown]
# LINK COLAB : https://colab.research.google.com/drive/12nCqCG8c_Pawd8kxha5pJlgrHRihcSf8?usp=sharing
#
# LINK GITHUB : https://github.com/fatuunreal/bengkelkoding/blob/4/A11_2022_14831_tgs_bk_3.ipynb

# %% [markdown]
# # 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from time import time
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # 2. Load Dataset dan Define Nama Kolom

# %% [markdown]
# ### Baca dataset

# %%
df = pd.read_csv('adult.csv', names=columns, na_values='?', skipinitialspace=True)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Definisikan nama kolom sesuai deskripsi dataset

# %%
columns = [
    'age', 'workclass', 'fnlwgt', 'education', 'education-num',
    'marital-status', 'occupation', 'relationship', 'race', 'sex',
    'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'
]

# %% [markdown]
# # 3. Cek Kualitas Data

# %% [markdown]
# ### Cek missing values

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %% [markdown]
# ### Cek duplikat

# %%
print("\nDuplikat Data:", df.duplicated().sum())
# Out:
# Duplikat Data: 24

# %% [markdown]
# ### Distribusi target

# %%
sns.countplot(x='income', data=df)
plt.title('Distribusi Income')
plt.show()

# %% [markdown]
# ### Korelasi fitur numerik

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Korelasi Fitur Numerik')
plt.show()

# %% [markdown]
# # 4. Penanganan Missing Values

# %% [markdown]
# ### Hapus baris dengan missing values

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Hapus kolom redundan

# %%
#kolom 'education-num' sudah mewakili dan memiliki fitur numerik
df.drop('education', axis=1, inplace=True)

# %% [markdown]
# ### Hapus duplikat

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # 5. Analisis Outlier

# %% [markdown]
# ### Visualisasi outlier untuk fitur numerik

# %%
numerical_cols = ['age', 'fnlwgt', 'capital-gain', 'capital-loss', 'hours-per-week']
plt.figure(figsize=(15, 5))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(1, 5, i)
    sns.boxplot(data=df, y=col)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Handling outlier dengan IQR untuk 'capital-gain' dan 'capital-loss'

# %%
Q1 = df[['capital-gain', 'capital-loss']].quantile(0.25)
Q3 = df[['capital-gain', 'capital-loss']].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[['capital-gain', 'capital-loss']] > (Q3 + 1.5 * IQR)).any(axis=1))]

# %% [markdown]
# # 6. Transformasi Data Kategorikal

# %% [markdown]
# ### Encoding variabel target

# %%
df['income'] = LabelEncoder().fit_transform(df['income'])

# %% [markdown]
# ### One-Hot Encoding untuk fitur kategorikal

# %%
categorical_cols = [
    'workclass', 'marital-status', 'occupation',
    'relationship', 'race', 'sex', 'native-country'
]

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ],
    remainder='passthrough'
)

X = df.drop('income', axis=1)
y = df['income']

# %% [markdown]
# # 7. Penanganan Class Imbalance dengan SMOTE

# %% [markdown]
# ### Transformasi data

# %%
X_processed = preprocessor.fit_transform(X)

# %% [markdown]
# ### Oversampling dengan SMOTE

# %%
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_processed, y)

# %% [markdown]
# # 8. Split Data dan Latih Model

# %% [markdown]
# ### Split data

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.3, random_state=42
)

# %% [markdown]
# ### Scaling untuk model yang memerlukan

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# Scaling
scaler = StandardScaler(with_mean=False)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Optimasi KNN
param_grid = {'n_neighbors': list(range(1, 21))}
grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)
grid.fit(X_train_scaled, y_train)

# Simpan model KNN terbaik
best_knn = grid.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-e6e44fa3c016> in <cell line: 0>()
#      10 param_grid = {'n_neighbors': list(range(1, 21))}
#      11 grid = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)
# ---> 12 grid.fit(X_train_scaled, y_train)
#      13
#      14 # Simpan model KNN terbaik
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
#    1026             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1569     def _run_search(self, evaluate_candidates):
#    1570         """Search all candidates in param_grid"""
# -> 1571         evaluate_candidates(ParameterGrid(self.param_grid))
#    1572
#    1573
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     968                     )
#     969
# --> 970                 out = parallel(
#     971                     delayed(_fit_and_score)(
#     972                         clone(base_estimator),
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#
# /usr/local/lib/python3.11/dist-packages/joblib/parallel.py in _get_sequential_output(self, iterable)
#    1845                 self.n_dispatched_batches += 1
#    1846                 self.n_dispatched_tasks += 1
# -> 1847                 res = func(*args, **kwargs)
#    1848                 self.n_completed_tasks += 1
#    1849                 self.print_progress()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#     140
#     141
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886
#     887         fit_time = time.time() - start_time
# --> 888         test_scores = _score(
#     889             estimator, X_test, y_test, scorer, score_params_test, error_score
#     890         )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py in _score(estimator, X_test, y_test, scorer, score_params, error_score)
#     947             scores = scorer(estimator, X_test, **score_params)
#     948         else:
# --> 949             scores = scorer(estimator, X_test, y_test, **score_params)
#     950     except Exception:
#     951         if isinstance(scorer, _MultimetricScorer):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py in __call__(self, estimator, *args, **kwargs)
#     470     def __call__(self, estimator, *args, **kwargs):
#     471         """Method that wraps estimator.score"""
# --> 472         return estimator.score(*args, **kwargs)
#     473
#     474     def __repr__(self):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_classification.py in score(self, X, y, sample_weight)
#     444             Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     445         """
# --> 446         return super().score(X, y, sample_weight)
#     447
#     448     def __sklearn_tags__(self):
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in score(self, X, y, sample_weight)
#     570         from .metrics import accuracy_score
#     571
# --> 572         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     573
#     574
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     260                 X, self._fit_X, self.metric
#     261             ):
# --> 262                 probabilities = self.predict_proba(X)
#     263                 if self.outputs_2d_:
#     264                     return np.stack(
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_classification.py in predict_proba(self, X)
#     369             # In that case, we do not need the distances to perform
#     370             # the weighting so we do not compute them.
# --> 371             neigh_ind = self.kneighbors(X, return_distance=False)
#     372             neigh_dist = None
#     373         else:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     904                 kwds = self.effective_metric_params_
#     905
# --> 906             chunked_results = list(
#     907                 pairwise_distances_chunked(
#     908                     X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2260             chunk_size = D_chunk.shape[0]
#    2261             D_chunk = reduce_func(D_chunk, sl.start)
# -> 2262             _check_chunk_size(D_chunk, chunk_size)
#    2263         yield D_chunk
#    2264
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/pairwise.py in _check_chunk_size(reduced, chunk_size)
#    2036
#    2037
# -> 2038 def _check_chunk_size(reduced, chunk_size):
#    2039     """Checks chunk is a sequence of expected size or a tuple of same."""
#    2040     if reduced is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model Training

# %%
models = {
    "Decision Tree": DecisionTreeClassifier(max_depth=5, random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "KNN": best_knn,
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "SVM": SVC(kernel='linear', random_state=42)
}

# %% [markdown]
# ### Pelatihan dan Evaluasi

# %%
results = []

for name, model in models.items():
    # Training
    start_time = time()

    if name in ["Logistic Regression", "SVM"]:
        model.fit(X_train_scaled, y_train)
    else:
        model.fit(X_train, y_train)

    train_time = time() - start_time

    # Prediction
    if name in ["Logistic Regression", "SVM"]:
        y_pred = model.predict(X_test_scaled)
    else:
        y_pred = model.predict(X_test)

    # Evaluation
    report = classification_report(y_test, y_pred, output_dict=True)

    results.append({
        'Model': name,
        'Accuracy': report['accuracy'],
        'Precision': report['weighted avg']['precision'],
        'Recall': report['weighted avg']['recall'],
        'F1-Score': report['weighted avg']['f1-score'],
        'Training Time': f"{train_time:.2f} sec"
    })

    # Confusion Matrix
    plt.figure(figsize=(5,4))
    sns.heatmap(confusion_matrix(y_test, y_pred),
                annot=True, fmt='d', cmap='Blues',
                xticklabels=['<=50K', '>50K'],
                yticklabels=['<=50K', '>50K'])
    plt.title(f'Confusion Matrix - {name}')
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %% [markdown]
# ### Menampilkna Hasil Perbandingan dan Visualisasi

# %%
display(results_df.style.background_gradient(cmap='Blues').set_properties(**{'text-align': 'left'}))
# Out:
# <style type="text/css">
# #T_07fac_row0_col0, #T_07fac_row0_col5, #T_07fac_row1_col0, #T_07fac_row1_col5, #T_07fac_row2_col0, #T_07fac_row2_col5, #T_07fac_row3_col0, #T_07fac_row3_col5, #T_07fac_row4_col0, #T_07fac_row4_col5 {
#   text-align: left;
# }
# #T_07fac_row0_col1, #T_07fac_row0_col3, #T_07fac_row0_col4 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_07fac_row0_col2 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_07fac_row1_col1, #T_07fac_row1_col2, #T_07fac_row1_col3, #T_07fac_row1_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_07fac_row2_col1, #T_07fac_row2_col2, #T_07fac_row2_col3, #T_07fac_row2_col4 {
#   background-color: #f7fbff;
#   color: #000000;
#   text-align: left;
# }
# #T_07fac_row3_col1, #T_07fac_row3_col3 {
#   background-color: #3888c1;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_07fac_row3_col2, #T_07fac_row3_col4 {
#   background-color: #3787c0;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_07fac_row4_col1, #T_07fac_row4_col3, #T_07fac_row4_col4 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
#   text-align: left;
# }
# #T_07fac_row4_col2 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
#   text-align: left;
# }
# </style>
# <table id="T_07fac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07fac_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_07fac_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_07fac_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_07fac_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_07fac_level0_col4" class="col_heading level0 col4" >F1-Score</th>
#       <th id="T_07fac_level0_col5" class="col_heading level0 col5" >Training Time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07fac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07fac_row0_col0" class="data row0 col0" >Decision Tree</td>
#       <td id="T_07fac_row0_col1" class="data row0 col1" >0.867302</td>
#       <td id="T_07fac_row0_col2" class="data row0 col2" >0.867754</td>
#       <td id="T_07fac_row0_col3" class="data row0 col3" >0.867302</td>
#       <td id="T_07fac_row0_col4" class="data row0 col4" >0.867301</td>
#       <td id="T_07fac_row0_col5" class="data row0 col5" >0.19 sec</td>
#     </tr>
#     <tr>
#       <th id="T_07fac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07fac_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_07fac_row1_col1" class="data row1 col1" >0.902460</td>
#       <td id="T_07fac_row1_col2" class="data row1 col2" >0.902756</td>
#       <td id="T_07fac_row1_col3" class="data row1 col3" >0.902460</td>
#       <td id="T_07fac_row1_col4" class="data row1 col4" >0.902417</td>
#       <td id="T_07fac_row1_col5" class="data row1 col5" >24.37 sec</td>
#     </tr>
#     <tr>
#       <th id="T_07fac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07fac_row2_col0" class="data row2 col0" >KNN</td>
#       <td id="T_07fac_row2_col1" class="data row2 col1" >0.681667</td>
#       <td id="T_07fac_row2_col2" class="data row2 col2" >0.687057</td>
#       <td id="T_07fac_row2_col3" class="data row2 col3" >0.681667</td>
#       <td id="T_07fac_row2_col4" class="data row2 col4" >0.680085</td>
#       <td id="T_07fac_row2_col5" class="data row2 col5" >0.00 sec</td>
#     </tr>
#     <tr>
#       <th id="T_07fac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07fac_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_07fac_row3_col1" class="data row3 col1" >0.828095</td>
#       <td id="T_07fac_row3_col2" class="data row3 col2" >0.830492</td>
#       <td id="T_07fac_row3_col3" class="data row3 col3" >0.828095</td>
#       <td id="T_07fac_row3_col4" class="data row3 col4" >0.827921</td>
#       <td id="T_07fac_row3_col5" class="data row3 col5" >0.17 sec</td>
#     </tr>
#     <tr>
#       <th id="T_07fac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07fac_row4_col0" class="data row4 col0" >SVM</td>
#       <td id="T_07fac_row4_col1" class="data row4 col1" >0.822778</td>
#       <td id="T_07fac_row4_col2" class="data row4 col2" >0.828559</td>
#       <td id="T_07fac_row4_col3" class="data row4 col3" >0.822778</td>
#       <td id="T_07fac_row4_col4" class="data row4 col4" >0.822222</td>
#       <td id="T_07fac_row4_col5" class="data row4 col5" >121.16 sec</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Visualisasi Perbandingan

# %%
# Visualization
plt.figure(figsize=(,4))
sns.barplot(x='Model', y='Accuracy', data=results_df, palette='viridis')
plt.title('Model Accuracy Comparison')
plt.ylim(0.5, 0.95)
plt.show()

# %% [markdown]
# # Kesimpulan
#
# ### 1. Random Forest menunjukkan performa terbaik dalam akurasi dan F1-Score
# ### 2. SVM memberikan keseimbangan precision-recall terbaik
# ### 3. Logistic Regression paling efisien dalam waktu training
# ### 4. Decision Tree cocok untuk interpretasi model
# ### 5. KNN kurang cocok untuk dataset ini
#
# # Rekomendasi:
# ### - Gunakan Random Forest untuk akurasi tertinggi
# ### - Pilih Logistic Regression untuk kebutuhan real-time
# ### - Gunakan Decision Tree untuk analisis interpretable
